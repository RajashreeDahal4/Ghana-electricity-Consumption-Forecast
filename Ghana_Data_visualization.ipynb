# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np
import tensorflow as tf
import os

# %%
path='/content/drive/MyDrive/final_data.xlsx'

# %%
import datetime
file_con=pd.read_excel(path,sheet_name='Electricity_consumption bilKWh')
file_con.head()
# file_dem=pd.read_excel(path,sheet_name='monthly demand')
# file_gen=pd.read_excel(path,sheet_name='monthly generation')
# file_pop=pd.read_excel(path,sheet_name='Population')
# file_gdp=pd.read_excel(path,sheet_name='GDP')
# file_con
# file_dem
# #file_gen
# file_pop
file_con
# Out:
#     Year  consumption          GDP  Population
# 0   1980      4.59300   4445228216    11056116
# 1   1981      4.65800   4222441615    11348289
# 2   1982      4.33900   4035994398    11676823
# 3   1983      2.27400   4057275043    12033575
# 4   1984      1.59000   4412279843    12405660
# 5   1985      2.48300   4504342149    12783613
# 6   1986      3.84400   5727602645    13164837
# 7   1987      4.11000   5074829932    13552021
# 8   1988      4.21000   5197840979    13947042
# 9   1989      4.62900   5251764264    14353410
# 10  1990      5.33600   5889174825    14773277
# 11  1991      5.71000   6596546196    15207367
# 12  1992      6.07700   6413901602    15653336
# 13  1993      5.83000   5966255778    16106765
# 14  1994      5.59300   5444560669    16561674
# 15  1995      5.62500   6465137615    17014057
# 16  1996      6.11300   6934984709    17462496
# 17  1997      6.26200   6891308594    17908985
# 18  1998      5.09700   7480968858    18357156
# 19  1999      5.68300   7719354839    18812359
# 20  2000      5.97922   4983024408    19278856
# 21  2001      6.46994   5314909954    19756928
# 22  2002      5.97348   6166330136    20246381
# 23  2003      4.47590   7632406553    20750299
# 24  2004      4.49038   8881368538    21272323
# 25  2005      5.18446  10744675210    21814642
# 26  2006      6.34640  20440893017    22379055
# 27  2007      5.31894  24827844950    22963946
# 28  2008      5.98232  28678701891    23563825
# 29  2009      6.10900  26048108185    24170940
# 30  2010      6.62300  32197272797    24779619
# 31  2011      7.62700  39337314810    25387710
# 32  2012      8.52100  41270954737    25996449
# 33  2013      9.02700  62405374786    26607642
# 34  2014      8.98100  53660342160    27224472
# 35  2015      8.24100  48564863888    27849205
# 36  2016      9.62600  55009730600    28481946
# 37  2017     10.16700  58998132330    29121471
# 38  2018     10.97300  65556464048    29767108
# 39  2019     11.56000  66983634224    30417856

# %%
Year=file_gdp['Year']
GDP=file_gdp['GDP']
plt.plot(Year, GDP)
plt.title('GDP Vs Year')
plt.xlabel('Year')
plt.ylabel('GDP')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-f541df8998db> in <module>()
# ----> 1 Year=file_gdp['Year']
#       2 GDP=file_gdp['GDP']
#       3 plt.plot(Year, GDP)
#       4 plt.title('GDP Vs Year')
#       5 plt.xlabel('Year')
#
# NameError: name 'file_gdp' is not defined

# %%
Year=file_pop['Year']
Population=file_pop['Population']
plt.plot(Year, Population)
plt.title('Population Vs Year')
plt.xlabel('Year')
plt.ylabel('Population')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-122-ca27837b185b> in <module>()
# ----> 1 Year=file_pop['Year']
#       2 Population=file_pop['Population']
#       3 plt.plot(Year, Population)
#       4 plt.title('Population Vs Year')
#       5 plt.xlabel('Year')
#
# NameError: name 'file_pop' is not defined

# %%
file_con.index=file_con.Year

# %%
file_con
# Out:
#       Year  consumption          GDP  Population
# Year
# 1980  1980      4.59300   4445228216    11056116
# 1981  1981      4.65800   4222441615    11348289
# 1982  1982      4.33900   4035994398    11676823
# 1983  1983      2.27400   4057275043    12033575
# 1984  1984      1.59000   4412279843    12405660
# 1985  1985      2.48300   4504342149    12783613
# 1986  1986      3.84400   5727602645    13164837
# 1987  1987      4.11000   5074829932    13552021
# 1988  1988      4.21000   5197840979    13947042
# 1989  1989      4.62900   5251764264    14353410
# 1990  1990      5.33600   5889174825    14773277
# 1991  1991      5.71000   6596546196    15207367
# 1992  1992      6.07700   6413901602    15653336
# 1993  1993      5.83000   5966255778    16106765
# 1994  1994      5.59300   5444560669    16561674
# 1995  1995      5.62500   6465137615    17014057
# 1996  1996      6.11300   6934984709    17462496
# 1997  1997      6.26200   6891308594    17908985
# 1998  1998      5.09700   7480968858    18357156
# 1999  1999      5.68300   7719354839    18812359
# 2000  2000      5.97922   4983024408    19278856
# 2001  2001      6.46994   5314909954    19756928
# 2002  2002      5.97348   6166330136    20246381
# 2003  2003      4.47590   7632406553    20750299
# 2004  2004      4.49038   8881368538    21272323
# 2005  2005      5.18446  10744675210    21814642
# 2006  2006      6.34640  20440893017    22379055
# 2007  2007      5.31894  24827844950    22963946
# 2008  2008      5.98232  28678701891    23563825
# 2009  2009      6.10900  26048108185    24170940
# 2010  2010      6.62300  32197272797    24779619
# 2011  2011      7.62700  39337314810    25387710
# 2012  2012      8.52100  41270954737    25996449
# 2013  2013      9.02700  62405374786    26607642
# 2014  2014      8.98100  53660342160    27224472
# 2015  2015      8.24100  48564863888    27849205
# 2016  2016      9.62600  55009730600    28481946
# 2017  2017     10.16700  58998132330    29121471
# 2018  2018     10.97300  65556464048    29767108
# 2019  2019     11.56000  66983634224    30417856

# %%
file_con.plot()

# %%
Consumption=file_con['consumption']
year=file_con['Year']
plt.plot(year, Consumption)
plt.title('Electricity Consumption Vs Year')
plt.xlabel('Year')
plt.ylabel('Electricity Consumption in Billion KWhr')
plt.show()

# %%
file_con['consumption'].plot(figsize=(12,5))

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
from random import random

# %%
file_con
# Out:
#       Year  consumption          GDP  Population
# Year
# 1980  1980      4.59300   4445228216    11056116
# 1981  1981      4.65800   4222441615    11348289
# 1982  1982      4.33900   4035994398    11676823
# 1983  1983      2.27400   4057275043    12033575
# 1984  1984      1.59000   4412279843    12405660
# 1985  1985      2.48300   4504342149    12783613
# 1986  1986      3.84400   5727602645    13164837
# 1987  1987      4.11000   5074829932    13552021
# 1988  1988      4.21000   5197840979    13947042
# 1989  1989      4.62900   5251764264    14353410
# 1990  1990      5.33600   5889174825    14773277
# 1991  1991      5.71000   6596546196    15207367
# 1992  1992      6.07700   6413901602    15653336
# 1993  1993      5.83000   5966255778    16106765
# 1994  1994      5.59300   5444560669    16561674
# 1995  1995      5.62500   6465137615    17014057
# 1996  1996      6.11300   6934984709    17462496
# 1997  1997      6.26200   6891308594    17908985
# 1998  1998      5.09700   7480968858    18357156
# 1999  1999      5.68300   7719354839    18812359
# 2000  2000      5.97922   4983024408    19278856
# 2001  2001      6.46994   5314909954    19756928
# 2002  2002      5.97348   6166330136    20246381
# 2003  2003      4.47590   7632406553    20750299
# 2004  2004      4.49038   8881368538    21272323
# 2005  2005      5.18446  10744675210    21814642
# 2006  2006      6.34640  20440893017    22379055
# 2007  2007      5.31894  24827844950    22963946
# 2008  2008      5.98232  28678701891    23563825
# 2009  2009      6.10900  26048108185    24170940
# 2010  2010      6.62300  32197272797    24779619
# 2011  2011      7.62700  39337314810    25387710
# 2012  2012      8.52100  41270954737    25996449
# 2013  2013      9.02700  62405374786    26607642
# 2014  2014      8.98100  53660342160    27224472
# 2015  2015      8.24100  48564863888    27849205
# 2016  2016      9.62600  55009730600    28481946
# 2017  2017     10.16700  58998132330    29121471
# 2018  2018     10.97300  65556464048    29767108
# 2019  2019     11.56000  66983634224    30417856

# %%
exo=pd.DataFrame()
#exo['GDP']=file_con['GDP']
exo['Population']=file_con['Population']

#print(exog1)
model = SARIMAX(file_con['consumption'], exog=exo, order=(0, 1, 0))
model_fit = model.fit(disp=0)
# make prediction
model_fit.summary()
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:215: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Statespace Model Results
# ==============================================================================
# Dep. Variable:            consumption   No. Observations:                   40
# Model:               SARIMAX(0, 1, 0)   Log Likelihood                 -95.749
# Date:                Sat, 12 Jun 2021   AIC                            195.499
# Time:                        07:56:12   BIC                            198.826
# Sample:                             0   HQIC                           196.692
#                                  - 40
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Population  4.236e-07   9.43e-06      0.045      0.964   -1.81e-05    1.89e-05
# sigma2        21.0459      6.912      3.045      0.002       7.498      34.594
# ===================================================================================
# Ljung-Box (Q):                         nan   Jarque-Bera (JB):                 7.48
# Prob(Q):                               nan   Prob(JB):                         0.02
# Heteroskedasticity (H):               0.68   Skew:                            -0.98
# Prob(H) (two-sided):                  0.49   Kurtosis:                         3.89
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
year_test=pd.DataFrame()
years_test=pd.DataFrame()

years_test['Year']=[2020,2021,2022,2023,2024,2025,2026]
year_test['population']=[3107.328852,3173.39732,3240.136553,3307.732588,3376.351688,3446.093448,3516.973269]
year_test['population']=year_test['population']*10000
year_test['Year']=years_test['Year']

# %%
year_test.index=year_test.Year
file_con['Population'].plot()
year_test['population'].plot()

# %%
file_con['Year'].append(years_test['Year'])

# %%
file_con['Population'].append(year_test['population'])

# %%
file_con

# %%
print(exo.shape)
# Out:
# (40, 1)

# %%
yearss_test=pd.DataFrame()
yearss_test['population']=[31073288.52,31733973.2,32401365.53,33077325.88,33763516.88,34460934.48,35169732.69]

# %%
years_test.index=years_test.Year
forecast = model_fit.predict(start=len(file_con['consumption']),end=len(file_con['consumption'])+len(years_test)-1,exog=yearss_test)
print(forecast.shape)
forecast = pd.DataFrame(forecast,columns=['Prediction'])
forecast['Year']=[2020,2021,2022,2023,2024,2025,2026]
forecast.index=forecast.Year
# Out:
# (7,)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:576: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)

# %%
forecast
# Out:
#       Prediction  Year
# Year
# 2020   11.837643  2020
# 2021   12.117511  2021
# 2022   12.400221  2022
# 2023   12.686560  2023
# 2024   12.977232  2024
# 2025   13.272661  2025
# 2026   13.572910  2026
